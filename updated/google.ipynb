# %%
from script import *

# %%
google = pd.read_csv('google.csv')
del google['Unnamed: 0']

# %%
google.columns= ['company','location','job-title','overall_ratings','work_balance_stars','culture_values_stars','carrer_opportunities_stars','comp_benefit_stars','senior_mangemnet_stars','helpful_count','year']
google.head()
# Out:
#   company           location                                 job-title  \
# 0  google  Mountain View, CA         Former Employee - Program Manager
# 1  google       New York, NY  Current Employee - Software Engineer III
# 2  google  Mountain View, CA     Current Employee - Anonymous Employee
# 3  google    Los Angeles, CA       Former Employee - Software Engineer
# 4  google  Mountain View, CA                    Former Employee - SDE2
#
#    overall_ratings  work_balance_stars  culture_values_stars  \
# 0              4.0                 2.0                   3.0
# 1              5.0                 5.0                   4.0
# 2              5.0                 2.0                   5.0
# 3              5.0                 5.0                   5.0
# 4              5.0                 4.0                   4.0
#
#    carrer_opportunities_stars  comp_benefit_stars  senior_mangemnet_stars  \
# 0                         3.0                 5.0                     3.0
# 1                         5.0                 5.0                     4.0
# 2                         5.0                 4.0                     5.0
# 3                         5.0                 5.0                     5.0
# 4                         4.0                 5.0                     4.0
#
#    helpful_count    year
# 0           2094  2013.0
# 1            949  2014.0
# 2            498  2015.0
# 3             49  2018.0
# 4              1  2018.0

# %%
fields = ['overall_ratings','work_balance_stars','culture_values_stars','carrer_opportunities_stars','comp_benefit_stars','senior_mangemnet_stars']
summary_google = google[fields].describe().transpose()
summary_google
# Out:
#                              count      mean       std  min  25%  50%  75%  \
# overall_ratings             4158.0  4.301347  0.964291  1.0  4.0  5.0  5.0
# work_balance_stars          4158.0  3.981481  1.085427  1.0  3.0  4.0  5.0
# culture_values_stars        4158.0  4.346320  0.903219  1.0  4.0  4.4  5.0
# carrer_opportunities_stars  4158.0  3.910053  1.100862  1.0  3.0  4.0  5.0
# comp_benefit_stars          4158.0  4.346441  0.864712  1.0  4.0  5.0  5.0
# senior_mangemnet_stars      4158.0  3.817220  1.103779  1.0  3.0  4.0  5.0
#
#                             max
# overall_ratings             5.0
# work_balance_stars          5.0
# culture_values_stars        5.0
# carrer_opportunities_stars  5.0
# comp_benefit_stars          5.0
# senior_mangemnet_stars      5.0

# %%
#Ratings over time for Google
fig, ax = plt.subplots(figsize=(15,9))
keys = ['year','company']
lines = ['overall_ratings','work_balance_stars','culture_values_stars','carrer_opportunities_stars','comp_benefit_stars','senior_mangemnet_stars']
google.groupby(keys)[lines].mean().unstack().plot(ax=ax,colormap = 'Set1')
_ = plt.xlabel("Years")
_ = plt.ylabel("Overall Ratings")
_ = plt.title("Overall Ratings per Year")
_ = plt.legend()

# %%
corr_matrix(google)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-67d4be5f6d52> in <module>
# ----> 1 corr_matrix(google)
#
# ~\QME\script.py in corr_matrix(df_company)
#      32
#      33 from sklearn.preprocessing import OrdinalEncoder
# ---> 34
#      35
#      36 def corr_matrix(df_company):
#
# NameError: name 'ord_enc' is not defined
